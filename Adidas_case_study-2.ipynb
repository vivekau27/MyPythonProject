# %%
from pyspark.sql.functions import col,isnan, when, count
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_df = spark.read.format("json").load("dbfs:/FileStore/shared_uploads/vivek.kaushik.bit@gmail.com/ol_cdump.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: 148163</div>

# %%
#display(my_df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_clean_df=my_df.filter(col('title').isNotNull()).filter(col('number_of_pages')>20).filter(col('publish_date')>1950)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_clean_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: 75439</div>

# %%
row1 = my_clean_df.agg({"number_of_pages": "max"}).collect()[0]
max_num_pages=row1["max(number_of_pages)"]
max_num_pages_df= my_clean_df.filter(col('number_of_pages')==max_num_pages)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(max_num_pages_df.select('title','number_of_pages'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>number_of_pages</th></tr></thead><tbody><tr><td>Nihon shokuminchi kenchikuron</td><td>48418</td></tr></tbody></table></div>

# %%
display(max_num_pages_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>alternate_names</th><th>authors</th><th>bio</th><th>birth_date</th><th>by_statement</th><th>contributions</th><th>contributors</th><th>copyright_date</th><th>covers</th><th>created</th><th>death_date</th><th>description</th><th>dewey_decimal_class</th><th>dewey_number</th><th>download_url</th><th>edition_name</th><th>excerpts</th><th>first_publish_date</th><th>first_sentence</th><th>full_title</th><th>fuller_name</th><th>genres</th><th>ia_box_id</th><th>ia_loaded_id</th><th>identifiers</th><th>isbn_10</th><th>isbn_13</th><th>isbn_invalid</th><th>isbn_odd_length</th><th>key</th><th>languages</th><th>last_modified</th><th>latest_revision</th><th>lc_classifications</th><th>lccn</th><th>links</th><th>location</th><th>name</th><th>notes</th><th>number_of_pages</th><th>ocaid</th><th>oclc_number</th><th>oclc_numbers</th><th>other_titles</th><th>pagination</th><th>personal_name</th><th>photos</th><th>physical_dimensions</th><th>physical_format</th><th>publish_country</th><th>publish_date</th><th>publish_places</th><th>publishers</th><th>purchase_url</th><th>revision</th><th>series</th><th>source_records</th><th>subject_people</th><th>subject_place</th><th>subject_places</th><th>subject_time</th><th>subject_times</th><th>subjects</th><th>subtitle</th><th>table_of_contents</th><th>title</th><th>title_prefix</th><th>type</th><th>uri_descriptions</th><th>uris</th><th>url</th><th>website</th><th>weight</th><th>work_title</th><th>work_titles</th><th>works</th></tr></thead><tbody><tr><td>null</td><td>List(List(null, /authors/OL5510271A, null))</td><td>null</td><td>null</td><td>Nishizawa Yasuhiko cho.</td><td>null</td><td>null</td><td>null</td><td>null</td><td>List(/type/datetime, 2009-01-07T22:47:41.819566)</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>880-03 Shohan.</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>List(4815805806)</td><td>List(9784815805807)</td><td>null</td><td>null</td><td>/books/OL22855337M</td><td>List(List(/languages/jpn))</td><td>List(/type/datetime, 2009-12-15T08:07:24.201731)</td><td>2</td><td>List(NA1555 .N575 2008)</td><td>List(2008543302)</td><td>null</td><td>null</td><td>null</td><td>{"type":"/type/text","value":"Includes bibliographical references and index."}</td><td>48418</td><td>null</td><td>List(216939675)</td><td>null</td><td>null</td><td>x, 484,18 p. :</td><td>null</td><td>null</td><td>null</td><td>null</td><td>ja </td><td>2008</td><td>List(Nagoya-shi)</td><td>List(Nagoya Daigaku Shuppankai)</td><td>null</td><td>2</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>List(Architecture -- Japan -- Colonies -- History., Architecture -- East Asia -- History.)</td><td>null</td><td>null</td><td>Nihon shokuminchi kenchikuron</td><td>null</td><td>List(/type/edition)</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>List(List(/works/OL12468635W))</td></tr></tbody></table></div>

# %%
#method2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import *


w = Window.orderBy(desc('number_of_pages'))
my_clean_df_interim=my_clean_df.withColumn('Rank',dense_rank().over(w))
my_clean_df_interim=my_clean_df_interim.filter(my_clean_df_interim.Rank == 1).drop(my_clean_df_interim.Rank)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(my_clean_df_interim.select('title','number_of_pages'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>number_of_pages</th></tr></thead><tbody><tr><td>Nihon shokuminchi kenchikuron</td><td>48418</td></tr></tbody></table></div>

# %%
display(my_clean_df_interim)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>alternate_names</th><th>authors</th><th>bio</th><th>birth_date</th><th>by_statement</th><th>contributions</th><th>contributors</th><th>copyright_date</th><th>covers</th><th>created</th><th>death_date</th><th>description</th><th>dewey_decimal_class</th><th>dewey_number</th><th>download_url</th><th>edition_name</th><th>excerpts</th><th>first_publish_date</th><th>first_sentence</th><th>full_title</th><th>fuller_name</th><th>genres</th><th>ia_box_id</th><th>ia_loaded_id</th><th>identifiers</th><th>isbn_10</th><th>isbn_13</th><th>isbn_invalid</th><th>isbn_odd_length</th><th>key</th><th>languages</th><th>last_modified</th><th>latest_revision</th><th>lc_classifications</th><th>lccn</th><th>links</th><th>location</th><th>name</th><th>notes</th><th>number_of_pages</th><th>ocaid</th><th>oclc_number</th><th>oclc_numbers</th><th>other_titles</th><th>pagination</th><th>personal_name</th><th>photos</th><th>physical_dimensions</th><th>physical_format</th><th>publish_country</th><th>publish_date</th><th>publish_places</th><th>publishers</th><th>purchase_url</th><th>revision</th><th>series</th><th>source_records</th><th>subject_people</th><th>subject_place</th><th>subject_places</th><th>subject_time</th><th>subject_times</th><th>subjects</th><th>subtitle</th><th>table_of_contents</th><th>title</th><th>title_prefix</th><th>type</th><th>uri_descriptions</th><th>uris</th><th>url</th><th>website</th><th>weight</th><th>work_title</th><th>work_titles</th><th>works</th></tr></thead><tbody><tr><td>null</td><td>List(List(null, /authors/OL5510271A, null))</td><td>null</td><td>null</td><td>Nishizawa Yasuhiko cho.</td><td>null</td><td>null</td><td>null</td><td>null</td><td>List(/type/datetime, 2009-01-07T22:47:41.819566)</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>880-03 Shohan.</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>List(4815805806)</td><td>List(9784815805807)</td><td>null</td><td>null</td><td>/books/OL22855337M</td><td>List(List(/languages/jpn))</td><td>List(/type/datetime, 2009-12-15T08:07:24.201731)</td><td>2</td><td>List(NA1555 .N575 2008)</td><td>List(2008543302)</td><td>null</td><td>null</td><td>null</td><td>{"type":"/type/text","value":"Includes bibliographical references and index."}</td><td>48418</td><td>null</td><td>List(216939675)</td><td>null</td><td>null</td><td>x, 484,18 p. :</td><td>null</td><td>null</td><td>null</td><td>null</td><td>ja </td><td>2008</td><td>List(Nagoya-shi)</td><td>List(Nagoya Daigaku Shuppankai)</td><td>null</td><td>2</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>List(Architecture -- Japan -- Colonies -- History., Architecture -- East Asia -- History.)</td><td>null</td><td>null</td><td>Nihon shokuminchi kenchikuron</td><td>null</td><td>List(/type/edition)</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>List(List(/works/OL12468635W))</td></tr></tbody></table></div>

# %%
my_clean_df_genre=my_clean_df.select('title',explode('genres').alias('Genres'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#display(my_clean_df_genre)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_clean_df
</td></tr><tr><td>Discography</td><td>5</td></tr><tr><td>Genealogy.</td><td>113</td></tr><tr><td>Problems, exercises, etc.</td><td>65</td></tr><tr><td>Excerpts</td><td>2</td></tr><tr><td>Greece, Modern</td><td>1</td></tr><tr><td>Autobiography.</td><td>2</td></tr><tr><td>Indonesia.</td><td>1</td></tr><tr><td>Diaries.</td><td>51</td></tr><tr><td>Classification.</td><td>20</td></tr><tr><td>Collections of games</td><td>1</td></tr><tr><td>Directories.</td><td>119</td></tr><tr><td>Biographies.</td><td>5</td></tr><tr><td>Translations into English</td><td>2</td></tr><tr><td>Outlines, syllabi, etc</td><td>27</td></tr><tr><td>Amateurs' manuals</td><td>2</td></tr><tr><td>Personal narratives, Scottish.</td><td>1</td></tr><tr><td>Apologetic works.</td><td>2</td></tr><tr><td>Songs and music</td><td>4</td></tr><tr><td>Research</td><td>2</td></tr><tr><td>Calendars.</td><td>1</td></tr><tr><td>Self-instruction.</td><td>13</td></tr><tr><td>Self-instruction</td><td>1</td></tr><tr><td>Greece, Modern.</td><td>1</td></tr><tr><td>Personal narratives, American</td><td>9</td></tr><tr><td>Portraits.</td><td>3 ...

# %%
w = Window.orderBy(desc('count'))
my_clean_df_genre_interim=my_clean_df_genre.withColumn('Rank',dense_rank().over(w))
my_clean_df_genre_interim=my_clean_df_genre_interim.filter(my_clean_df_genre_interim.Rank <= 5).drop(my_clean_df_genre_interim.Rank)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(my_clean_df_genre_interim)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Genres</th><th>count</th></tr></thead><tbody><tr><td>Fiction.</td><td>3300</td></tr><tr><td>Biography.</td><td>2360</td></tr><tr><td>Juvenile literature.</td><td>1538</td></tr><tr><td>Exhibitions.</td><td>836</td></tr><tr><td>Juvenile fiction.</td><td>525</td></tr></tbody></table></div>

# %%
my_clean_df_coauth=my_clean_df.select('title',explode('authors'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#display(my_clean_df_coauth)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_clean_df_coauth.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- title: string (nullable = true)
# -- col: struct (nullable = true)
#     |-- author: struct (nullable = true)
#     |    |-- key: string (nullable = true)
#     |-- key: string (nullable = true)
#     |-- type: string (nullable = true)
#
# </div>

# %%
my_clean_df_coauth=my_clean_df_coauth.select(col('title'),col('col.author.key').alias('author_key'),col('col.key'),col('col.type'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_clean_df_coauth.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- title: string (nullable = true)
# -- author_key: string (nullable = true)
# -- key: string (nullable = true)
# -- type: string (nullable = true)
#
# </div>

# %%
#display(my_clean_df_coauth)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_clean_df_coauth.filter(col('author_key').isNotNull()).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: 0</div>

# %%
display(my_df.filter(col('title')=='Cancionero de Puerto Rico'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>alternate_names</th><th>authors</th><th>bio</th><th>birth_date</th><th>by_statement</th><th>contributions</th><th>contributors</th><th>copyright_date</th><th>covers</th><th>created</th><th>death_date</th><th>description</th><th>dewey_decimal_class</th><th>dewey_number</th><th>download_url</th><th>edition_name</th><th>excerpts</th><th>first_publish_date</th><th>first_sentence</th><th>full_title</th><th>fuller_name</th><th>genres</th><th>ia_box_id</th><th>ia_loaded_id</th><th>identifiers</th><th>isbn_10</th><th>isbn_13</th><th>isbn_invalid</th><th>isbn_odd_length</th><th>key</th><th>languages</th><th>last_modified</th><th>latest_revision</th><th>lc_classifications</th><th>lccn</th><th>links</th><th>location</th><th>name</th><th>notes</th><th>number_of_pages</th><th>ocaid</th><th>oclc_number</th><th>oclc_numbers</th><th>other_titles</th><th>pagination</th><th>personal_name</th><th>photos</th><th>physical_dimensions</th><th>physical_format</th><th>publish_country</th><th>publish_date</th><th>publish_places</th><th>publishers</th><th>purchase_url</th><th>revision</th><th>series</th><th>source_records</th><th>subject_people</th><th>subject_place</th><th>subject_places</th><th>subject_time</th><th>subject_times</th><th>subjects</th><th>subtitle</th><th>table_of_contents</th><th>title</th><th>title_prefix</th><th>type</th><th>uri_descriptions</th><th>uris</th><th>url</th><th>website</th><th>weight</th><th>work_title</th><th>work_titles</th><th>works</th></tr></thead><tbody><tr><td>null</td><td>List(List(List(/authors/OL5360212A), null, {"key":"/type/author_role"}))</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>List(/type/datetime, 2009-12-11T06:30:00.004446)</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>1954</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>/works/OL12268504W</td><td>null</td><td>List(/type/datetime, 2010-12-03T19:10:20.603637)</td><td>3</td><td>List(M1621.F47 C35 1954)</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>3</td><td>null</td><td>null</td><td>null</td><td>null</td><td>List(Puerto Rico)</td><td>null</td><td>null</td><td>List(Folk songs, Spanish, Songs (High voice) with piano, Spanish Folk songs)</td><td>null</td><td>null</td><td>Cancionero de Puerto Rico</td><td>null</td><td>List(/type/work)</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td></tr></tbody></table></div>

# %%
my_clean_df_coauth_grped=my_clean_df_coauth.groupBy('key').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#display(my_clean_df_coauth_grped.orderBy(col('count').desc()))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>count</th></tr></thead><tbody><tr><td>/authors/OL1224818A</td><td>236</td></tr><tr><td>/authors/OL4283462A</td><td>116</td></tr><tr><td>/authors/OL785848A</td><td>106</td></tr><tr><td>/authors/OL1926829A</td><td>80</td></tr><tr><td>/authors/OL883775A</td><td>75</td></tr><tr><td>/authors/OL171521A</td><td>72</td></tr><tr><td>/authors/OL432880A</td><td>56</td></tr><tr><td>/authors/OL4287637A</td><td>54</td></tr><tr><td>/authors/OL113611A</td><td>53</td></tr><tr><td>/authors/OL724353A</td><td>49</td></tr><tr><td>/authors/OL6559140A</td><td>48</td></tr><tr><td>/authors/OL4900362A</td><td>47</td></tr><tr><td>/authors/OL6532917A</td><td>46</td></tr><tr><td>/authors/OL161167A</td><td>45</td></tr><tr><td>/authors/OL1162080A</td><td>42</td></tr><tr><td>/authors/OL4282449A</td><td>38</td></tr><tr><td>/authors/OL546900A</td><td>37</td></tr><tr><td>/authors/OL5268670A</td><td>37</td></tr><tr><td>/authors/OL5004509A</td><td>37</td></tr><tr><td>/authors/OL4361397A</td><td>35</td></tr><tr><td>/authors/OL5230527A</td><td>35</td></tr><tr><td>/authors/OL2732923A</td><td>34</td></tr><tr><td>/authors/OL1222373A</td><td>34</td></tr><tr><td>/authors/OL4152392A</td><td>33</td></tr><tr><td>/authors/OL4991545A</td><td>33</td></tr><tr><td>/authors/OL220942A</td><td>33</td></tr><tr><td>/authors/OL1370547A</td><td>32</td></tr><tr><td>/authors/OL126038A</td><td>32</td></tr><tr><td>/authors/OL1318679A</td><td>32</td></tr><tr><td>/authors/OL5771800A</td><td>32</td></tr><tr><td>/authors/
()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-----+
#                 key|count|
# +-------------------+-----+
# /authors/OL1224818A|  236|
# /authors/OL4283462A|  116|
#  /authors/OL785848A|  106|
# /authors/OL1926829A|   80|
#  /authors/OL883775A|   75|
#  /authors/OL171521A|   72|
#  /authors/OL432880A|   56|
# /authors/OL4287637A|   54|
#  /authors/OL113611A|   53|
#  /authors/OL724353A|   49|
# /authors/OL6559140A|   48|
# /authors/OL4900362A|   47|
# /authors/OL6532917A|   46|
#  /authors/OL161167A|   45|
# /authors/OL1162080A|   42|
# /authors/OL4282449A|   38|
# /authors/OL5004509A|   37|
# /authors/OL5268670A|   37|
#  /authors/OL546900A|   37|
# /authors/OL4361397A|   35|
# +-------------------+-----+
# only showing top 20 rows
#
# </div>

# %%
w = Window.orderBy(desc('count'))
my_clean_df_coauth_grped_interim=my_clean_df_coauth_grped.withColumn('Rank',dense_rank().over(w))
my_clean_df_coauth_grped_interim=my_clean_df_coauth_grped_interim.filter(my_clean_df_coauth_grped_interim.Rank <= 5).drop(my_clean_df_coauth_grped_interim.Rank)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(my_clean_df_coauth_grped_interim)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>key</th><th>count</th></tr></thead><tbody><tr><td>/authors/OL1224818A</td><td>236</td></tr><tr><td>/authors/OL4283462A</td><td>116</td></tr><tr><td>/authors/OL785848A</td><td>106</td></tr><tr><td>/authors/OL1926829A</td><td>80</td></tr><tr><td>/authors/OL883775A</td><td>75</td></tr></tbody></table></div>

# %%
my_clean_df_publish=my_clean_df.select('title','publish_date',explode('authors'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#df = df.filter(df.colD.between(200, 400))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#display(my_clean_df_publish)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_clean_df_publish.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- title: string (nullable = true)
# -- publish_date: string (nullable = true)
# -- col: struct (nullable = true)
#     |-- author: struct (nullable = true)
#     |    |-- key: string (nullable = true)
#     |-- key: string (nullable = true)
#     |-- type: string (nullable = true)
#
# </div>

# %%
my_clean_df_publish_flat=my_clean_df_publish.select(col('title'),'publish_date',col('col.author.key').alias('author_key'),col('col.key'),col('col.type'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_clean_df_publish_flat.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- title: string (nullable = true)
# -- publish_date: string (nullable = true)
# -- author_key: string (nullable = true)
# -- key: string (nullable = true)
# -- type: string (nullable = true)
#
# </div>

# %%
#display(my_clean_df_publish_flat)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_clean_df_publish_flat.filter(col('key').isNull()).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: 0</div>

# %%
my_clean_df_publish_flat.filter(col('author_key').isNotNull()).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: 0</div>

# %%
my_clean_df_publish_flat.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: 75359</div>

# %%
my_clean_df_publish_flat.groupBy('publish_date').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+-----+
# publish_date|count|
# +------------+-----+
#         3606|    1|
#         1953|  622|
#         1957|  740|
#         1987| 1279|
#         1956|  664|
#         1958|  789|
#         1972| 1081|
#         1988| 1300|
#         1977|  755|
#         1971| 1136|
#         1984| 1106|
#         1982|  970|
#         2005| 1217|
#         2000| 1071|
#         1965| 1347|
#         1962| 1128|
#         1954|  666|
#         1981|  871|
#         1978|  789|
#         1974| 1200|
# +------------+-----+
# only showing top 20 rows
#
# </div>

# %%
#df = df.filter(df.colD.between(200, 400))
#my_clean_df_publish_flat = my_clean_df_publish_flat.filter(my_clean_df_publish_flat.publish_date.between(1950, 1970))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#display(my_clean_df_publish_flat)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#display(my_clean_df_publish_flat.groupBy('publish_date','key').count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
my_clean_df_publish_flat_grp=my_clean_df_publish_flat.groupBy('publish_date','key').count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#display(my_clean_df_publish_flat_grp)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(my_clean_df_publish_flat_grp.groupBy('publish_date').count().orderBy('publish_date'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>
A, null)</td></tr><tr><td>Lezioni zurighesi sul Petrarca</td><td>1955</td><td>null</td><td>List(null, /authors/OL135548A, null)</td></tr><tr><td>El saber ginecologico del padre Feijoo</td><td>1964</td><td>null</td><td>List(null, /authors/OL6535899A, null)</td></tr><tr><td>Reflex French</td><td>1966</td><td>null</td><td>List(null, /authors/OL133670A, null)</td></tr><tr><td>Some aspects of the relationship between creativity and self-disclosure</td><td>1976</td><td>null</td><td>List(null, /authors/OL6535900A, null)</td></tr><tr><td>Creative responses to time in the novels of William Faulkner</td><td>1976</td><td>null</td><td>List(null, /authors/OL6535901A, null)</td></tr><tr><td>Creativity and delinquency as a function of physiological arousal and the stimulation-seeking motive</td><td>1976</td><td>null</td><td>List(null, /authors/OL6535902A, null)</td></tr><tr><td>Shaw and death</td><td>1976</td><td>null</td><td>List(null, /authors/OL6535903A, null)</td></tr><tr><td>Adventuring with books</td><td>1961</td><td>null</td><td>List(null, /authors/OL6533579A, null)</td></tr><tr><td>La lune, l'Amérique</td><td>1969</td><td>null</td><td>List(null, /authors/OL5570662A, null)</td></tr><tr><td>A resource guide for secondary school teaching</td><td>1978</td><td>null</td><td>List(null, /authors/OL6535905A, null)</td></tr><tr><td>Instructor's resource manual to accompany Modern production/operations management, seventh edition</td><td>1983</td><td>null</td><td>List(null, /authors/OL4328637A, null)</td></tr><tr><td>Stories from Greek history.</td><td>1965</td><td>null</td><td>List(null, /authors/OL5459805A, null)</td></tr><tr><td>German short stories.</td><td>1964</td><td>null</td><td>List(null, /authors/OL978880A, null)</td></tr><tr><td>Az ezüst koporsó</td><td>1968</td><td>null</td><td>List(null, /authors/OL5503749A, null)</td></tr><tr><td>Taccuino somalo</td><td>1960</td><td>null</td><td>List(null, /authors/OL2165208A, null)</td></tr><tr><td>Esercizi e conversazioni di lingua viva</td><td>1962</td><td>null</td><td>List(null, /authors/OL4409259A, null)</td></tr><tr><td>Amal'ezulu</td><td>1960</td><td>null</td><td>List(null, /authors/OL1786598A, null)</td></tr><tr><td>On economic theory and socialism</td><td>1955</td><td>null</td><td>List(null, /authors/OL4529355A, null)</td></tr><tr><td>Table tennis illustrated</td><td>1953</td><td>null</td><td>List(null, /authors/OL2261944A, null)</td></tr><tr><td>Review and synthesis of research on the economics of vocational education</td><td>1968</td><td>null</td><td>List(null, /authors/OL2840476A, null)</td></tr><tr><td>A permi nyelvek ösi képzöi</td><td>1965</td><td>null</td><td>List(null, /authors/OL6535907A, null)</td></tr><tr><td>Complaintes</td><td>1963</td><td>null</td><td>List(null, /authors/OL6535908A, null)</td></tr><tr><td>The synthesis of potential anti-malarial compounds by coupling phospholan-3-one-1-oxides with quinolines</td><td>1978</td><td>null</td><td>List(null, /authors/OL6535910A, null)</td></tr><tr><td>Meine Fibel</td><td>1970</td><td>null</td><td>List(null, /authors/OL1558306A, null)</td></tr><tr><td>Inkondlo kaZulu</td><td>1957</td><td>null</td><td>List(null, /authors/OL1786598A, null)</td></tr> ...

# %%
my_clean_df_publish_pmonth.filter(col('first_publish_date').isNotNull()).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[51]: 0</div>
